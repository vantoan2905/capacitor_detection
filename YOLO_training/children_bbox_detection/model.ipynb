# %%
# !labelme2yolo --json_dir D:\Work\codev2\code\train_data_2
# Out:
# [2024-10-07T08:23:29Z INFO  labelme2yolo] Starting the conversion process...
# [2024-10-07T08:23:31Z INFO  labelme2yolo] Read and parsed 2277 JSON files.
# [2024-10-07T08:23:51Z INFO  labelme2yolo] Creating dataset.yaml file...
# [2024-10-07T08:23:51Z INFO  labelme2yolo] Conversion process completed successfully.

# %%
# !yolo cfg=D:\Work\codev2\code\work_code\model_code\config.yaml

# %%
import ultralytics
from ultralytics import YOLO

# %%
import torch
print(torch.cuda.is_available())
model = YOLO('yolov8n.yaml')
# Out:
# True

# %%
if __name__ == "__main__":
    
    config = r"D:\Work\codev2\code\work_code\model_code\config.yaml"


    results = model.train(cfg=config)
# Out:
# New https://pypi.org/project/ultralytics/8.3.6 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.103  Python-3.10.14 torch-1.13.0 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# WARNING  Upgrade to torch>=2.0.0 for deterministic training.
# ...

# %%
path = r"D:\Work\codev2\code\work_code\model_code\yolo_project\experiment3\weights\best.pt"
model = YOLO(path)

result = model.predict(source= r"D:\Work\codev2\code\test_data" , conf=0.5, iou=0.3, save=True, save_txt=True, )
# Out:
# image 1/486 D:\Work\codev2\code\test_data\336_0.bmp: 832x1216 4 numb_boxs, 43.8ms
# image 2/486 D:\Work\codev2\code\test_data\336_1.bmp: 768x1216 20 numb_boxs, 14.2ms
# image 3/486 D:\Work\codev2\code\test_data\336_2.bmp: 832x1216 6 numb_boxs, 14.3ms
# image 4/486 D:\Work\codev2\code\test_data\336_3.bmp: 896x1216 31 numb_boxs, 13.2ms
# image 5/486 D:\Work\codev2\code\test_data\336_4.bmp: 832x1216 51 numb_boxs, 15.2ms
# image 6/486 D:\Work\codev2\code\test_data\336_5.bmp: 896x1216 1 numb_box, 14.2ms
# image 7/486 D:\Work\codev2\code\test_data\336_6.bmp: 832x1216 48 numb_boxs, 16.3ms
# image 8/486 D:\Work\codev2\code\test_data\336_7.bmp: 768x1216 37 numb_boxs, 15.9ms
# image 9/486 D:\Work\codev2\code\test_data\336_8.bmp: 832x1216 (no detections), 14.6ms
# image 10/486 D:\Work\codev2\code\test_data\337_0.bmp: 832x1216 2 numb_boxs, 11.4ms
# image 11/486 D:\Work\codev2\code\test_data\337_1.bmp: 768x1216 (no detections), 14.5ms
# ...
