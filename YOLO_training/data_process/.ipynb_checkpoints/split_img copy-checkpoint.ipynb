# %%
import cv2
import matplotlib.pyplot as plt
import math
import os
import pandas as pd
import json

# %%
def plot_img(list_img):
    plt.figure(figsize=(30, 15))
    for i, img_slice in enumerate(list_img):
        plt.subplot(1, len(list_img), i + 1)
        plt.imshow(img_slice)
        plt.title(f"Slice {i+1}")
        plt.axis('off')

    plt.show()

# %%
def check_box(slice, box):
    img= cv2.imread(slice)
    height, width, channels = img.shape
    _x1, _y1, _x2, _y2, _x3, _y3, _x4, _y4 = box
    _x1, _y1, _x2, _y2, _x3, _y3, _x4, _y4 = float(_x1), float(_y1), float(_x2), float(_y2), float(_x3), float(_y3), float(_x4), float(_y4)
    if (0 <= _x1 <= width and 0 <= _y1 <= height and
        0 <= _x2 <= width and 0 <= _y2 <= height and
        0 <= _x3 <= width and 0 <= _y3 <= height and
        0 <= _x4 <= width and 0 <= _y4 <= height):
        return True
    return False

def split_img(img):
    img = cv2.imread(img)
    h, w, _ = img.shape
    step_x = 1824
    step_y = 1216

    num_of_slice_w = w // step_x
    num_of_slice_h = h // step_y

    print(f"Img size of slice width: {step_x}")
    print(f"Img size of slice height: {step_y}")

    slices_2d = []
    for i in range(num_of_slice_w):
        row_slices = []
        for j in range(num_of_slice_h):
            start_x = i * step_x
            start_y = j * step_y
            end_x = min((i + 1) * step_x, w)
            end_y = min((j + 1) * step_y, h)

            img_slice = img[start_y:end_y, start_x:end_x]
            row_slices.append(img_slice)
        
        slices_2d.append(row_slices)

    return slices_2d

# %%
def save_slice(list_slice, new_path, file):
    path = os.path.join(new_path, file)
    for i, row in enumerate(list_slice):
        for j, _slice in enumerate(row): 
            cv2.imwrite(path[:-4] + f"x{i}y{j}.bmp", _slice)

# %%
def save_label_json(_data, new_path , file):

        shapes = []
        for row in _data:
            shape = {
                "label": "",
                "points": [
                    [row[0], row[1]],
                    [row[2], row[3]],
                    [row[4], row[5]],
                    [row[6], row[7]],
                ],
            "group_id": None,
            "description": "",
            "shape_type": "polygon",
            "flags": {},
            "mask": None          
            }
            shapes.append(shape)

        # Create the final JSON structure
        data = {
            "version": "5.5.0",
            "flags": {},
            "shapes": shapes,
            "imagePath": file[:3] + ".bmp",
            "imageData": None,
            "imageHeight": 3648,
            "imageWidth": 5472
        }

        # save the json file
        with open(os.path.join(new_path, file[:3] + ".json"), 'w') as f:
            json.dump(data, f, indent=4)

# %%
def load_img_and_bbox(path, new_path):
    # split img
    for folder in os.listdir(path):
        for file in os.listdir(os.path.join(path, folder)):
            path_file = os.path.join(path, folder, file)

            ############################################
            ############################################
            if file.endswith(".bmp"):
                print(path_file)
                lists_slice = split_img(path_file)

                save_slice(lists_slice,new_path,file)
    
    for img in os.listdir(new_path):
        slice_path = os.path.join(new_path, img)
        lists_bbox = []
        print(slice_path)
        
        for index, folder in enumerate(os.listdir(path)):
            label = "black_box" if index < 2 else "numb_box"  # Correct label assignment
            
            for file in os.listdir(os.path.join(path, folder)):
                path_file = os.path.join(path, folder, file)

                # Check if the CSV file exists and matches the naming condition
                if path_file.endswith(".csv") and file[:-4] == img[:-8]:
                    # Check if the file is not null (exists)
                    if not os.path.exists(path_file):
                        print(f"File not found: {path_file}")
                        continue
                    
                    with open(path_file, 'r') as f:
                        csv_reader = pd.read_csv(f)
                        
                        # Read existing JSON if it exists
                        json_file_path = os.path.join(new_path, img[:-4] + ".json")
                        shapes = []
                        if os.path.exists(json_file_path):
                            with open(json_file_path, 'r') as json_f:
                                data = json.load(json_f)
                                shapes = data.get("shapes", [])

                        for index, bbox in csv_reader.iterrows():
                            # Ensure bbox has the expected columns
                            if len(bbox) >= 8:  # Check for minimum number of columns
                                shape = {
                                    "label": label,
                                    "points": [
                                        [bbox['Top_Left_X'], bbox['Top_Left_Y']],
                                        [bbox['Top_Right_X'], bbox['Top_Right_Y']],
                                        [bbox['Bottom_Right_X'], bbox['Bottom_Right_Y']],
                                        [bbox['Bottom_Left_X'], bbox['Bottom_Left_Y']],
                                    ],
                                    "group_id": None,
                                    "description": "",
                                    "shape_type": "polygon",
                                    "flags": {},
                                    "mask": None          
                                }
                                shapes.append(shape)

                        # Create the final JSON structure
                        data = {
                            "version": "5.5.0",
                            "flags": {},
                            "shapes": shapes,
                            "imagePath": file[:3] + ".bmp",
                            "imageData": None,
                            "imageHeight": 3648,
                            "imageWidth": 5472
                        }

                        # Save the JSON file
                        with open(json_file_path, 'w') as json_f:
                            json.dump(data, json_f, indent=4)

        # Convert lists_bbox to DataFrame and save
        if lists_bbox:
            lists_bbox_df = pd.DataFrame(lists_bbox)
            save_label_json(lists_bbox_df, new_path, img)

# %%
load_img_and_bbox(r"D:\Work\codev2\data\work_data\19.9_work_1", r"D:\Work\codev2\code\work_code\model_code\test_data")
# Out:
# D:\Work\codev2\code\work_code\model_code\test_data\000x0y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\000x0y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\000x0y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\000x1y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\000x1y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\000x1y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\000x2y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\000x2y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\000x2y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\001x0y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\001x0y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\001x0y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\001x1y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\001x1y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\001x1y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\001x2y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\001x2y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\001x2y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\003x0y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\003x0y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\003x0y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\003x1y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\003x1y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\003x1y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\003x2y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\003x2y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\003x2y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\006x0y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\006x0y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\006x0y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\006x1y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\006x1y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\006x1y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\006x2y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\006x2y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\006x2y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\008x0y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\008x0y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\008x0y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\008x1y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\008x1y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\008x1y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\008x2y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\008x2y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\008x2y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\017x0y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\017x0y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\017x0y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\017x1y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\017x1y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\017x1y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\017x2y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\017x2y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\017x2y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\018x0y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\018x0y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\018x0y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\018x1y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\018x1y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\018x1y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\018x2y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\018x2y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\018x2y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\019x0y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\019x0y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\019x0y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\019x1y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\019x1y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\019x1y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\019x2y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\019x2y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\019x2y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\021x0y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\021x0y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\021x0y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\021x1y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\021x1y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\021x1y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\021x2y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\021x2y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\021x2y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\023x0y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\023x0y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\023x0y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\023x1y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\023x1y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\023x1y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\023x2y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\023x2y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\023x2y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\026x0y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\026x0y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\026x0y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\026x1y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\026x1y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\026x1y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\026x2y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\026x2y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\026x2y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\029x0y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\029x0y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\029x0y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\029x1y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\029x1y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\029x1y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\029x2y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\029x2y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\029x2y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\039x0y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\039x0y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\039x0y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\039x1y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\039x1y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\039x1y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\039x2y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\039x2y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\039x2y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\040x0y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\040x0y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\040x0y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\040x1y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\040x1y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\040x1y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\040x2y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\040x2y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\040x2y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\041x0y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\041x0y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\041x0y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\041x1y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\041x1y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\041x1y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\041x2y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\041x2y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\041x2y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\042x0y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\042x0y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\042x0y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\042x1y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\042x1y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\042x1y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\042x2y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\042x2y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\042x2y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\043x0y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\043x0y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\043x0y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\043x1y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\043x1y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\043x1y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\043x2y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\043x2y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\043x2y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\044x0y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\044x0y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\044x0y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\044x1y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\044x1y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\044x1y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\044x2y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\044x2y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\044x2y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\045x0y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\045x0y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\045x0y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\045x1y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\045x1y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\045x1y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\045x2y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\045x2y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\045x2y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\046x0y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\046x0y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\046x0y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\046x1y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\046x1y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\046x1y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\046x2y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\046x2y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\046x2y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\047x0y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\047x0y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\047x0y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\047x1y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\047x1y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\047x1y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\047x2y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\047x2y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\047x2y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\049x0y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\049x0y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\049x0y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\049x1y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\049x1y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\049x1y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\049x2y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\049x2y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\049x2y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\050x0y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\050x0y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\050x0y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\050x1y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\050x1y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\050x1y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\050x2y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\050x2y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\050x2y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\051x0y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\051x0y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\051x0y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\051x1y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\051x1y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\051x1y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\051x2y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\051x2y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\051x2y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\052x0y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\052x0y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\052x0y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\052x1y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\052x1y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\052x1y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\052x2y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\052x2y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\052x2y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\053x0y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\053x0y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\053x0y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\053x1y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\053x1y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\053x1y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\053x2y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\053x2y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\053x2y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\056x0y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\056x0y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\056x0y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\056x1y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\056x1y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\056x1y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\056x2y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\056x2y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\056x2y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\065x0y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\065x0y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\065x0y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\065x1y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\065x1y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\065x1y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\065x2y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\065x2y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\065x2y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\067x0y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\067x0y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\067x0y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\067x1y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\067x1y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\067x1y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\067x2y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\067x2y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\067x2y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\068x0y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\068x0y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\068x0y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\068x1y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\068x1y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\068x1y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\068x2y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\068x2y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\068x2y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\069x0y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\069x0y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\069x0y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\069x1y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\069x1y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\069x1y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\069x2y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\069x2y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\069x2y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\090x0y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\090x0y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\090x0y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\090x1y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\090x1y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\090x1y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\090x2y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\090x2y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\090x2y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\095x0y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\095x0y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\095x0y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\095x1y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\095x1y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\095x1y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\095x2y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\095x2y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\095x2y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\098x0y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\098x0y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\098x0y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\098x1y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\098x1y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\098x1y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\098x2y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\098x2y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\098x2y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\099x0y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\099x0y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\099x0y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\099x1y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\099x1y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\099x1y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\099x2y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\099x2y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\099x2y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\107x0y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\107x0y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\107x0y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\107x1y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\107x1y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\107x1y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\107x2y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\107x2y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\107x2y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\109x0y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\109x0y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\109x0y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\109x1y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\109x1y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\109x1y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\109x2y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\109x2y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\109x2y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\110x0y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\110x0y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\110x0y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\110x1y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\110x1y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\110x1y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\110x2y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\110x2y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\110x2y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\112x0y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\112x0y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\112x0y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\112x1y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\112x1y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\112x1y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\112x2y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\112x2y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\112x2y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\113x0y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\113x0y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\113x0y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\113x1y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\113x1y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\113x1y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\113x2y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\113x2y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\113x2y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\114x0y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\114x0y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\114x0y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\114x1y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\114x1y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\114x1y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\114x2y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\114x2y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\114x2y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\115x0y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\115x0y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\115x0y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\115x1y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\115x1y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\115x1y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\115x2y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\115x2y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\115x2y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\116x0y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\116x0y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\116x0y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\116x1y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\116x1y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\116x1y2.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\116x2y0.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\116x2y1.bmp
# D:\Work\codev2\code\work_code\model_code\test_data\116x2y2.bmp
