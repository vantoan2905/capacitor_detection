# %%
import os 
import pandas as pd
import numpy as np
import shutil

# %%
for folder in os.listdir(r"D:\Work\codev2\data\final_data\final_19.9v1"):
    for file in os.listdir(os.path.join(r"D:\Work\codev2\data\final_data\final_19.9v1", folder)):
        if file.endswith(".json"):
            print(os.path.join(r"D:\Work\codev2\data\final_data\final_19.9v1", folder, file))
            shutil.copy(os.path.join(r"D:\Work\codev2\data\final_data\final_19.9v1", folder, file), r"D:\Work\codev2\code\train_data_2")
        if file.endswith(".bmp"):
            print(os.path.join(r"D:\Work\codev2\data\final_data\final_19.9v1", folder, file))
            shutil.copy(os.path.join(r"D:\Work\codev2\data\final_data\final_19.9v1", folder, file), r"D:\Work\codev2\code\train_data_2")
for folder in os.listdir(r"D:\Work\codev2\data\final_data\final_20.09"):
    for file in os.listdir(os.path.join(r"D:\Work\codev2\data\final_data\final_20.09", folder)):
        if file.endswith(".json"):
            print(os.path.join(r"D:\Work\codev2\data\final_data\final_20.09", folder, file))
            shutil.copy(os.path.join(r"D:\Work\codev2\data\final_data\final_20.09", folder, file), r"D:\Work\codev2\code\train_data_2")
        if file.endswith(".bmp"):
            print(os.path.join(r"D:\Work\codev2\data\final_data\final_20.09", folder, file))
            shutil.copy(os.path.join(r"D:\Work\codev2\data\final_data\final_20.09", folder, file), r"D:\Work\codev2\code\train_data_2")
for folder in os.listdir(r"D:\Work\codev2\data\final_data\final_24.09"):
    for file in os.listdir(os.path.join(r"D:\Work\codev2\data\final_data\final_24.09", folder)):
        if file.endswith(".json"): 
            print(os.path.join(r"D:\Work\codev2\data\final_data\final_24.09", folder, file))
            shutil.copy(os.path.join(r"D:\Work\codev2\data\final_data\final_24.09", folder, file), r"D:\Work\codev2\code\train_data_2")
        if file.endswith(".bmp"): 
            print(os.path.join(r"D:\Work\codev2\data\final_data\final_24.09", folder, file))
            shutil.copy(os.path.join(r"D:\Work\codev2\data\final_data\final_24.09", folder, file), r"D:\Work\codev2\code\train_data_2")
# Out:
# D:\Work\codev2\data\final_data\final_19.9v1\C05 VS-W\053.bmp
# D:\Work\codev2\data\final_data\final_19.9v1\C05 VS-W\053.json
# D:\Work\codev2\data\final_data\final_19.9v1\C05KVS-Y\019.bmp
# D:\Work\codev2\data\final_data\final_19.9v1\C05KVS-Y\019.json
# D:\Work\codev2\data\final_data\final_19.9v1\C05KVS-Y\067.bmp
# D:\Work\codev2\data\final_data\final_19.9v1\C05KVS-Y\067.json
# D:\Work\codev2\data\final_data\final_19.9v1\C05KVS-Y\068.bmp
# D:\Work\codev2\data\final_data\final_19.9v1\C05KVS-Y\068.json
# D:\Work\codev2\data\final_data\final_19.9v1\C10 CSH-Y\000.bmp
# D:\Work\codev2\data\final_data\final_19.9v1\C10 CSH-Y\000.json
# D:\Work\codev2\data\final_data\final_19.9v1\C10 CSH-Y\001.bmp
# D:\Work\codev2\data\final_data\final_19.9v1\C10 CSH-Y\001.json
# D:\Work\codev2\data\final_data\final_19.9v1\C10 CSH-Y\003.bmp
# D:\Work\codev2\data\final_data\final_19.9v1\C10 CSH-Y\003.json
# D:\Work\codev2\data\final_data\final_19.9v1\C10CSHUY\090.bmp
# ...
